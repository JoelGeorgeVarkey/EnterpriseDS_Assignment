# %%
# importing Libraries
import pandas as pd
import missingno as msno
import plotly.express as px
import numpy as np

# %matplotlib inline

# %%
Data_URL_Link = r"https://covid.ourworldindata.org/data/owid-covid-data.csv"

# %%
df_country_info = pd.read_csv(Data_URL_Link, sep = ',')
# df_country_info.head(5)

# %%
# df_country_info['location']
df_country_info.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')

# %%
df_GER = df_country_info[df_country_info['location']=='Germany']
df_GER =  df_GER.reset_index(drop=True)
df_US = df_country_info[df_country_info['location']=='United States']
df_US =  df_US.reset_index(drop=True)
df_IND = df_country_info[df_country_info['location']=='India']
df_IND =  df_IND.reset_index(drop=True)

df_GER

# %%
# df_GER.loc[len(df_GER.index)] = [df_GER] 
# df_all = df_GER.append(df_GER, ignore_index = True)
df_all = pd.concat([df_GER, df_US, df_IND], ignore_index = True)
df_all.reset_index()

df_all
# Out:
#       index iso_code continent location        date  total_cases  new_cases  \
# 0         0      DEU    Europe  Germany  2020-01-27          1.0        1.0
# 1         1      DEU    Europe  Germany  2020-01-28          4.0        3.0
# 2         2      DEU    Europe  Germany  2020-01-29          4.0        0.0
# 3         3      DEU    Europe  Germany  2020-01-30          4.0        0.0
# 4         4      DEU    Europe  Germany  2020-01-31          5.0        1.0
# ...     ...      ...       ...      ...         ...          ...        ...
# 2646   2646      IND      Asia    India  2022-06-23   43362294.0    17336.0
# 2647   2647      IND      Asia    India  2022-06-24   43378234.0    15940.0
# 2648   2648      IND      Asia    India  2022-06-25   43389973.0    11739.0
# 2649   2649      IND      Asia    India  2022-06-26   43407046.0    17073.0
# 2650   2650      IND      Asia    India  2022-06-27   43418839.0    11793.0
#
#       new_cases_smoothed  total_deaths  new_deaths  ...  female_smokers  \
# 0                    NaN           NaN         NaN  ...            28.2
# 1                    NaN           NaN         NaN  ...            28.2
# 2                    NaN           NaN         NaN  ...            28.2
# 3                    NaN           NaN         NaN  ...            28.2
# 4                    NaN           NaN         NaN  ...            28.2
# ...                  ...           ...         ...  ...             ...
# 2646           13102.429      524954.0        13.0  ...             1.9
# 2647           13491.571      524974.0        20.0  ...             1.9
# 2648           13325.857      524999.0        25.0  ...             1.9
# 2649           13939.000      525020.0        21.0  ...             1.9
# 2650           14206.143      525047.0        27.0  ...             1.9
#
#       male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0             33.1                     NaN                        8.00
# 1             33.1                     NaN                        8.00
# 2             33.1                     NaN                        8.00
# 3             33.1                     NaN                        8.00
# 4             33.1                     NaN                        8.00
# ...            ...                     ...                         ...
# 2646          20.6                   59.55                        0.53
# 2647          20.6                   59.55                        0.53
# 2648          20.6                   59.55                        0.53
# 2649          20.6                   59.55                        0.53
# 2650          20.6                   59.55                        0.53
#
#       life_expectancy  human_development_index  \
# 0               81.33                    0.947
# 1               81.33                    0.947
# 2               81.33                    0.947
# 3               81.33                    0.947
# 4               81.33                    0.947
# ...               ...                      ...
# 2646            69.66                    0.645
# 2647            69.66                    0.645
# 2648            69.66                    0.645
# 2649            69.66                    0.645
# 2650            69.66                    0.645
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                      NaN                          NaN
# 1                                      NaN                          NaN
# 2                                      NaN                          NaN
# 3                                      NaN                          NaN
# 4                                      NaN                          NaN
# ...                                    ...                          ...
# 2646                                   NaN                          NaN
# 2647                                   NaN                          NaN
# 2648                                   NaN                          NaN
# 2649                                   NaN                          NaN
# 2650                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 0                  NaN                                      NaN
# 1                  NaN                                      NaN
# 2                  NaN                                      NaN
# 3                  NaN                                      NaN
# 4                  NaN                                      NaN
# ...                ...                                      ...
# 2646               NaN                                      NaN
# 2647               NaN                                      NaN
# 2648               NaN                                      NaN
# 2649               NaN                                      NaN
# 2650               NaN                                      NaN
#
# [2651 rows x 68 columns]

# %%
df_all_reduce = df_all[["date","location","people_vaccinated", "population"]]
df_all_reduce
# Out:
#             date location  people_vaccinated    population
# 0     2020-01-27  Germany                NaN  8.390047e+07
# 1     2020-01-28  Germany                NaN  8.390047e+07
# 2     2020-01-29  Germany                NaN  8.390047e+07
# 3     2020-01-30  Germany                NaN  8.390047e+07
# 4     2020-01-31  Germany                NaN  8.390047e+07
# ...          ...      ...                ...           ...
# 2646  2022-06-23    India       1.015258e+09  1.393409e+09
# 2647  2022-06-24    India       1.015454e+09  1.393409e+09
# 2648  2022-06-25    India       1.015664e+09  1.393409e+09
# 2649  2022-06-26    India       1.015813e+09  1.393409e+09
# 2650  2022-06-27    India       1.015878e+09  1.393409e+09
#
# [2651 rows x 4 columns]

# %%
df_all_reduce['vaccination_rate_over_time']=df_all_reduce['people_vaccinated']/df_all_reduce['population']

# %%
fig = px.line(df_all_reduce, x="date", y="vaccination_rate_over_time",color = 'location', title='Covid cases')
fig.show()
