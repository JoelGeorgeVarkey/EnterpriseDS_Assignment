# %%
import pandas as pd

# %matplotlib inline

# %% [markdown]
# # Data set loading for Visualization

# %%
url = r"https://covid.ourworldindata.org/data/owid-covid-data.csv"

# %%
df_country_info = pd.read_csv(url, sep = ',')

# %%
df_country_info
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 196998      ZWE    Africa     Zimbabwe  2022-06-22     255049.0      130.0
# 196999      ZWE    Africa     Zimbabwe  2022-06-23     255136.0       87.0
# 197000      ZWE    Africa     Zimbabwe  2022-06-24     255309.0      173.0
# 197001      ZWE    Africa     Zimbabwe  2022-06-25     255309.0        0.0
# 197002      ZWE    Africa     Zimbabwe  2022-06-26     255355.0       46.0
#
# ...

# %%
df_country_info.head(5)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
df_country_info.to_csv('covid_full_data.csv', ';')

# %%
# df_country_info['location']
df_country_info['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
df_country_info[df_country_info['location']=='Germany']
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 66436      DEU    Europe  Germany  2020-01-27          1.0        1.0
# 66437      DEU    Europe  Germany  2020-01-28          4.0        3.0
# 66438      DEU    Europe  Germany  2020-01-29          4.0        0.0
# 66439      DEU    Europe  Germany  2020-01-30          4.0        0.0
# 66440      DEU    Europe  Germany  2020-01-31          5.0        1.0
# ...        ...       ...      ...         ...          ...        ...
# 67313      DEU    Europe  Germany  2022-06-22   27573585.0   119360.0
# 67314      DEU    Europe  Germany  2022-06-23   27681775.0   108190.0
# 67315      DEU    Europe  Germany  2022-06-24   27771111.0    89336.0
# 67316      DEU    Europe  Germany  2022-06-25   27771112.0        1.0
# 67317      DEU    Europe  Germany  2022-06-26   27771911.0      799.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df_GER = df_country_info[df_country_info['location']=='Germany']

# %%
df_GER.reset_index(drop=True)
# Out:
#     iso_code continent location        date  total_cases  new_cases  \
# 0        DEU    Europe  Germany  2020-01-27          1.0        1.0
# 1        DEU    Europe  Germany  2020-01-28          4.0        3.0
# 2        DEU    Europe  Germany  2020-01-29          4.0        0.0
# 3        DEU    Europe  Germany  2020-01-30          4.0        0.0
# 4        DEU    Europe  Germany  2020-01-31          5.0        1.0
# ..       ...       ...      ...         ...          ...        ...
# 877      DEU    Europe  Germany  2022-06-22   27573585.0   119360.0
# 878      DEU    Europe  Germany  2022-06-23   27681775.0   108190.0
# 879      DEU    Europe  Germany  2022-06-24   27771111.0    89336.0
# 880      DEU    Europe  Germany  2022-06-25   27771112.0        1.0
# 881      DEU    Europe  Germany  2022-06-26   27771911.0      799.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df_GER = df_GER.reset_index(drop=True)

# %%
import missingno as msno

# %%
df_GER.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
msno.matrix(df_GER[['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
       'new_cases_smoothed', 'total_deaths', 'new_deaths',
       'new_deaths_smoothed', 'total_cases_per_million',
       'new_cases_per_million', 'new_cases_smoothed_per_million',
       'total_deaths_per_million', 'new_deaths_per_million',
       'new_deaths_smoothed_per_million', 'reproduction_rate']])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # basic plotting line chart example

# %%
import plotly.express as px

# df = px.data.gapminder().query("country=='Canada'")
fig = px.line(df_GER, x="date", y="total_cases", title='Covid cases')
fig.show()

# %%
df_GER['total_cases']/df_GER['population']
# Out:
# 0      1.191888e-08
# 1      4.767554e-08
# 2      4.767554e-08
# 3      4.767554e-08
# 4      5.959442e-08
#            ...
# 877    3.286464e-01
# 878    3.299359e-01
# 879    3.310007e-01
# 880    3.310007e-01
# 881    3.310102e-01
# Length: 882, dtype: float64

# %%
b_GER = df_country_info['location']=='Germany'
b_US = df_country_info['location']=='United States'

# %%
b_all = sum(b_US | b_GER)

# %%
"notebook.output.textLineLimit": 2000
# pd.set_option('display.max_rows',500)
# Out:
#   Input In [48]
#     "notebook.output.textLineLimit": 2000
#     ^
# SyntaxError: illegal target for annotation

# %%
# df_my_list = df_country_info[b_all]
df_my_list = df_country_info[b_US]

# %%
df_my_list
# Out:
#        iso_code      continent       location        date  total_cases  \
# 185611      USA  North America  United States  2020-01-22          1.0
# 185612      USA  North America  United States  2020-01-23          1.0
# 185613      USA  North America  United States  2020-01-24          2.0
# 185614      USA  North America  United States  2020-01-25          2.0
# 185615      USA  North America  United States  2020-01-26          5.0
# ...         ...            ...            ...         ...          ...
# 186493      USA  North America  United States  2022-06-22   86636306.0
# 186494      USA  North America  United States  2022-06-23   86757621.0
# 186495      USA  North America  United States  2022-06-24   86909716.0
# 186496      USA  North America  United States  2022-06-25   86949088.0
# 186497      USA  North America  United States  2022-06-26   86967639.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
fig = px.line(df_my_list, x="date", y="total_cases",color = 'location', title='Covid cases')
fig.show()

# %%
df_my_list['total_cases_norm']=df_my_list['total_cases']/df_my_list['population']
# Out:
# C:\Users\joelg\AppData\Local\Temp\ipykernel_3732\3659698054.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig = px.line(df_my_list, x="date", y="total_cases_norm",color = 'location', title='Covid cases')
fig.show()
